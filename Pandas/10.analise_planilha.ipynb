# %%
import pandas as pd

# %%
df = pd.read_excel("dados/futebol.xlsx")
df
# Out:
#          Times  Partidas_Jogadas  Vitorias  Empates  Derrotas  Gols_Pro  \
# 0     Flamengo                10         7        2         1        22
# 1    São Paulo                10         6        1         3        16
# 2    Palmeiras                10         5        3         2        18
# 3       Santos                10         4        3         3        14
# 4  Corinthians                10         3        2         5        10
#
#    Gols_Contra  Saldo de gols  Pontos
# 0           10             12      23
# 1           15              1      19
# 2           12              6      18
# 3           16             -2      15
# 4           20            -10      11

# %%
df.dtypes
# Out:
# Times               object
# Partidas_Jogadas     int64
# Vitorias             int64
# Empates              int64
# Derrotas             int64
# Gols_Pro             int64
# Gols_Contra          int64
# Saldo de gols        int64
# Pontos               int64
# dtype: object

# %%
df.describe()
# Out:
# <bound method NDFrame.describe of          Times  Partidas_Jogadas  Vitorias  Empates  Derrotas  Gols_Pro  \
# 0     Flamengo                10         7        2         1        22
# 1    São Paulo                10         6        1         3        16
# 2    Palmeiras                10         5        3         2        18
# 3       Santos                10         4        3         3        14
# 4  Corinthians                10         3        2         5        10
#
#    Gols_Contra  Saldo de gols  Pontos
# 0           10             12      23
# 1           15              1      19
# 2           12              6      18
# 3           16             -2      15
# 4           20            -10      11  >

# %%
df.head(3)
# Out:
#        Times  Partidas_Jogadas  Vitorias  Empates  Derrotas  Gols_Pro  \
# 0   Flamengo                10         7        2         1        22
# 1  São Paulo                10         6        1         3        16
# 2  Palmeiras                10         5        3         2        18
#
#    Gols_Contra  Saldo de gols  Pontos
# 0           10             12      23
# 1           15              1      19
# 2           12              6      18

# %%
df.tail(2)
# Out:
#          Times  Partidas_Jogadas  Vitorias  Empates  Derrotas  Gols_Pro  \
# 3       Santos                10         4        3         3        14
# 4  Corinthians                10         3        2         5        10
#
#    Gols_Contra  Saldo de gols  Pontos
# 3           16             -2      15
# 4           20            -10      11

# %%
# Análise de desempenho por time:

desempenho = df[["Times", "Pontos", "Vitorias", "Saldo de gols"]].set_index("Times")
desempenho
# Out:
#              Pontos  Vitorias  Saldo de gols
# Times
# Flamengo         23         7             12
# São Paulo        19         6              1
# Palmeiras        18         5              6
# Santos           15         4             -2
# Corinthians      11         3            -10
