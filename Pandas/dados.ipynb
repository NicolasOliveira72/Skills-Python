# %%
import pandas as pd

# %%
data = {
    "Produto" : ["Arroz", "Feijão", "Abacate"],
    "Quantidade" : [23, 47, 19],
    "Preço" : [5.00, 6.40, 9.75]
}

df = pd.DataFrame(data)

# %%
df
# Out:
#    Produto  Quantidade  Preço
# 0    Arroz          23   5.00
# 1   Feijão          47   6.40
# 2  Abacate          19   9.75

# %%
df["Total"] = df["Quantidade"] * df["Preço"]

# %%
df
# Out:
#    Produto  Quantidade  Preço   Total
# 0    Arroz          23   5.00  115.00
# 1   Feijão          47   6.40  300.80
# 2  Abacate          19   9.75  185.25
